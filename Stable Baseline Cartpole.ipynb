# %%
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 1.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from stable-baselines3[extra]) (3.7.1)
# Collecting gymnasium==0.28.1
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 7.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cloudpickle in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: torch>=1.11 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.0.1)
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 10.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.20 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.24.2)
# Requirement already satisfied: pygame in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.1.0)
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from stable-baselines3[extra]) (9.4.0)
# Collecting tensorboard>=2.9.1
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 12.7 MB/s eta 0:00:0000:0100:01
# Collecting autorom[accept-rom-license]~=0.6.0
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 5.7 MB/s eta 0:00:00:00:0100:01
# Collecting rich
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 14.0 MB/s eta 0:00:00
# Collecting shimmy[atari]~=0.2.1
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting psutil
#   Downloading psutil-5.9.5-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 kB 10.4 MB/s eta 0:00:00
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (6.1.0)
# Collecting click
#   Downloading click-8.1.6-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.28.2)
# Requirement already satisfied: importlib-resources in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (5.12.0)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 9.3 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1
#   Downloading ale_py-0.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.1 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 7.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: setuptools>=41.0.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (67.6.0)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 5.7 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 11.9 MB/s eta 0:00:0000:0100:01
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.56.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 12.4 MB/s eta 0:00:0000:0100:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.40.0)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 10.4 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 4.7 MB/s eta 0:00:00:00:01
# Requirement already satisfied: jinja2 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.11.3)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.10.3.66)
# Requirement already satisfied: filelock in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (3.12.2)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (10.9.0.58)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.4.0.1)
# Requirement already satisfied: networkx in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.14.3)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (8.5.0.96)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.4.91)
# Requirement already satisfied: triton==2.0.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (10.2.10.91)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: sympy in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.101)
# Requirement already satisfied: lit in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (16.0.6)
# Requirement already satisfied: cmake in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (3.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from pandas->stable-baselines3[extra]) (2022.7)
# Requirement already satisfied: pytz>=2020.1 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from pandas->stable-baselines3[extra]) (2022.7.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from rich->stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 5.3 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<2.0 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.14)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gymnasium==0.28.1->stable-baselines3[extra]) (3.15.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.0.1)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 3.3 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 7.4 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446659 sha256=be0865f4de978ed2deaa83c66da070dbd84cac7031f19ae5bab8e66c30e560f6
#   Stored in directory: /home/jhebeler/.cache/pip/wheels/84/55/09/367b3a18e3c0cf9c69af93d77818a6ea19493121c65af499f6
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, tqdm, tensorboard-data-server, pyasn1, psutil, protobuf, opencv-python, oauthlib, mdurl, MarkupSafe, jax-jumpy, grpcio, click, cachetools, absl-py, werkzeug, rsa, requests-oauthlib, pyasn1-modules, pandas, markdown-it-py, markdown, gymnasium, AutoROM.accept-rom-license, autorom, ale-py, shimmy, rich, google-auth, google-auth-oauthlib, tensorboard, stable-baselines3
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
# Successfully installed AutoROM.accept-rom-license-0.6.1 MarkupSafe-2.1.3 absl-py-1.4.0 ale-py-0.8.1 autorom-0.6.1 cachetools-5.3.1 click-8.1.6 farama-notifications-0.0.4 google-auth-2.22.0 google-auth-oauthlib-1.0.0 grpcio-1.56.2 gymnasium-0.28.1 jax-jumpy-1.0.0 markdown-3.4.3 markdown-it-py-3.0.0 mdurl-0.1.2 oauthlib-3.2.2 opencv-python-4.8.0.74 pandas-2.0.3 protobuf-4.23.4 psutil-5.9.5 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rich-13.4.2 rsa-4.9 shimmy-0.2.1 stable-baselines3-2.0.0 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tqdm-4.65.0 werkzeug-2.3.6

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('CartPole-v0')

# %%
episodes = 15
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info,extra = env.step(action)
        score += reward

    print("Episode: {} Score: {}".format(episode, score))

env.close()
# Out:
# Episode: 1 Score: 23.0
# Episode: 2 Score: 17.0
# Episode: 3 Score: 15.0
# Episode: 4 Score: 17.0
# Episode: 5 Score: 10.0
# Episode: 6 Score: 13.0
# Episode: 7 Score: 14.0
# Episode: 8 Score: 16.0
# Episode: 9 Score: 27.0
# Episode: 10 Score: 33.0
# Episode: 11 Score: 20.0
# Episode: 12 Score: 18.0
# Episode: 13 Score: 21.0
# Episode: 14 Score: 15.0
# Episode: 15 Score: 36.0

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space.sample()
# Out:
# array([-4.5104089e+00, -3.0824748e+38,  6.3789010e-02, -2.8716093e+38],
#       dtype=float32)

# %%
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 982  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008596087 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00556     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.04        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 49.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 3           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010823855 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0982      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 32.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 4           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010821836 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 5           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006702928 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 6           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006759233 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 65          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 133          |
# |    iterations           | 7            |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0064828536 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 55.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 131          |
# |    iterations           | 8            |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0028749916 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00677     |
# |    value_loss           | 48           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 9            |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0061499695 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 26.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 10          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008258726 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 25.7        |
# -----------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\mg\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _ = model.predict(state)
        state, reward, done, info = env.step(action)
        score += reward

    print("Episode: {} Score: {}".format(episode, score))

env.close()
# Out:
# /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:234: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Episode: 1 Score: [200.]
# Episode: 2 Score: [200.]
# Episode: 3 Score: [200.]
# Episode: 4 Score: [179.]
# Episode: 5 Score: [200.]

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = r"bestsolution"

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=195, verbose=1)

eval_callback = EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000,
                            best_model_save_path= save_path, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1112 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0078103887 |
# |    clip_fraction        | 0.0894       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -0.0169      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.95         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 54.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 3           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009568098 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0611      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.02        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 40.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 4            |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0083738705 |
# |    clip_fraction        | 0.0986       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0226      |
# |    value_loss           | 54.1         |
# ------------------------------------------
# /home/jhebeler/.conda/envs/conda_env/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=194.20 +/- 7.91
# Episode length: 194.20 +/- 7.91
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 194         |
# |    mean_reward          | 194         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010494733 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 64.9        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 144   |
# |    iterations      | 5     |
# |    time_elapsed    | 70    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 6           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007105368 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 60          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 7           |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009933898 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 61.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 8            |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0034940634 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 63.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 132          |
# |    iterations           | 9            |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0025159377 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.27         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 21.6         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0046353075 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.28         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00651     |
# |    value_loss           | 18.6         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 195

# %%
net_arch = [dict(pi=[64,64,64], vf=[64,64,64])]

# %%
model = PPO('MlpPolicy', env, verbose=1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 839  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 540        |
# |    iterations           | 2          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01303708 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.684     |
# |    explained_variance   | -0.00875   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.1        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0198    |
# |    value_loss           | 37.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012224556 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 35.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 4            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0102297235 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0242      |
# |    value_loss           | 40.2         |
# ------------------------------------------
# C:\Users\mg\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=196.80 +/- 6.40
# Episode length: 196.80 +/- 6.40
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 197         |
# |    mean_reward          | 197         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.012784746 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 49.8        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 418   |
# |    iterations      | 5     |
# |    time_elapsed    | 24    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 6            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0066348193 |
# |    clip_fraction        | 0.0749       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0149      |
# |    value_loss           | 54.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 7           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006002875 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00798    |
# |    value_loss           | 45.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0052231797 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.89         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 27           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 9            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0059789955 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.96         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 28.8         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005187258 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.533      |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.23        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 28.6        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 377   |
# |    iterations      | 10    |
# |    time_elapsed    | 54    |
# |    total_timesteps | 20480 |
# ------------------------------

# %%
from stable_baselines3 import DQN

# %%
nodel = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
nodel.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 62       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3097     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2961     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 254      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3208     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3344     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 457      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3186     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3152     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 610      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3284     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 724      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3342     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 850      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3159     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 958      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3261     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3172     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3285     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3345     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 